# %%
#Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | seoul
# Processing Record 2 of Set 1 | kruisfontein
# Processing Record 3 of Set 1 | bonthe
# Processing Record 4 of Set 1 | port hawkesbury
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | waingapu
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | tynda
# Processing Record 10 of Set 1 | labytnangi
# Processing Record 11 of Set 1 | kangaba
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | itaituba
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | mogadishu
# Processing Record 21 of Set 1 | sao filipe
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | provideniya
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | iwaki
# Processing Record 26 of Set 1 | margate
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | moba
# Processing Record 29 of Set 1 | vilyuysk
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | okandja
# City not found. Skipping...
# Processing Record 32 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | saryg-sep
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | vitim
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | pyay
# Processing Record 41 of Set 1 | vilanova del cami
# Processing Record 42 of Set 1 | east london
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | alvaraes
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | caravelas
# Processing Record 49 of Set 1 | palmer
# Processing Record 50 of Set 1 | saldanha
# Processing Record 1 of Set 2 | cravo norte
# Processing Record 2 of Set 2 | hamilton
# Processing Record 3 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 2 | lakes entrance
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | narsaq
# Processing Record 7 of Set 2 | north platte
# Processing Record 8 of Set 2 | migori
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | broken hill
# Processing Record 12 of Set 2 | souillac
# Processing Record 13 of Set 2 | asau
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | kibaya
# Processing Record 17 of Set 2 | pokhara
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | ventspils
# Processing Record 22 of Set 2 | wakkanai
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | eureka
# Processing Record 26 of Set 2 | gat
# Processing Record 27 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | vila franca do campo
# Processing Record 30 of Set 2 | tevaitoa
# Processing Record 31 of Set 2 | andenes
# Processing Record 32 of Set 2 | sligo
# Processing Record 33 of Set 2 | moron
# Processing Record 34 of Set 2 | namatanai
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | mumford
# Processing Record 37 of Set 2 | krasnoselkup
# Processing Record 38 of Set 2 | kuala terengganu
# Processing Record 39 of Set 2 | katsuura
# Processing Record 40 of Set 2 | cabedelo
# Processing Record 41 of Set 2 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | osa
# Processing Record 44 of Set 2 | naryan-mar
# Processing Record 45 of Set 2 | kavieng
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | zhigansk
# Processing Record 49 of Set 2 | tomatlan
# Processing Record 50 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-augustin
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | necochea
# Processing Record 4 of Set 3 | vostok
# Processing Record 5 of Set 3 | kristiinankaupunki
# Processing Record 6 of Set 3 | richards bay
# Processing Record 7 of Set 3 | cabo san lucas
# Processing Record 8 of Set 3 | geraldton
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 3 | awbari
# Processing Record 14 of Set 3 | port-gentil
# Processing Record 15 of Set 3 | nkhata bay
# Processing Record 16 of Set 3 | joensuu
# Processing Record 17 of Set 3 | half moon bay
# Processing Record 18 of Set 3 | sumbe
# Processing Record 19 of Set 3 | saskylakh
# Processing Record 20 of Set 3 | redmond
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | taylor
# Processing Record 23 of Set 3 | ranfurly
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | constitucion
# Processing Record 26 of Set 3 | skjervoy
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | ust-kuyga
# Processing Record 29 of Set 3 | bauchi
# Processing Record 30 of Set 3 | qasigiannguit
# Processing Record 31 of Set 3 | indiana
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | georgetown
# Processing Record 34 of Set 3 | petropavlovka
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | santiago
# Processing Record 37 of Set 3 | pochutla
# Processing Record 38 of Set 3 | vardo
# Processing Record 39 of Set 3 | upernavik
# Processing Record 40 of Set 3 | hermanus
# Processing Record 41 of Set 3 | saint-pierre
# Processing Record 42 of Set 3 | tiarei
# Processing Record 43 of Set 3 | hangal
# Processing Record 44 of Set 3 | alice springs
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | ketchikan
# Processing Record 47 of Set 3 | dikson
# Processing Record 48 of Set 3 | kuah
# Processing Record 49 of Set 3 | fairmont
# Processing Record 50 of Set 3 | bathsheba
# Processing Record 1 of Set 4 | laguna
# Processing Record 2 of Set 4 | thompson
# Processing Record 3 of Set 4 | coquimbo
# Processing Record 4 of Set 4 | pangody
# Processing Record 5 of Set 4 | fukue
# Processing Record 6 of Set 4 | knysna
# Processing Record 7 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 4 | yellowknife
# Processing Record 9 of Set 4 | pitkyaranta
# Processing Record 10 of Set 4 | cockburn town
# Processing Record 11 of Set 4 | pisco
# Processing Record 12 of Set 4 | camacha
# Processing Record 13 of Set 4 | talaja
# Processing Record 14 of Set 4 | gerash
# Processing Record 15 of Set 4 | mar del plata
# Processing Record 16 of Set 4 | vaitape
# Processing Record 17 of Set 4 | santa vitoria do palmar
# Processing Record 18 of Set 4 | madison
# Processing Record 19 of Set 4 | sur
# Processing Record 20 of Set 4 | komsomolskiy
# Processing Record 21 of Set 4 | kidodi
# Processing Record 22 of Set 4 | roma
# Processing Record 23 of Set 4 | mariana
# Processing Record 24 of Set 4 | broome
# Processing Record 25 of Set 4 | mandalgovi
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | cidreira
# Processing Record 28 of Set 4 | sorland
# Processing Record 29 of Set 4 | tessalit
# Processing Record 30 of Set 4 | othonoi
# City not found. Skipping...
# Processing Record 31 of Set 4 | manokwari
# Processing Record 32 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 4 | novikovo
# Processing Record 34 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 4 | poum
# Processing Record 36 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 37 of Set 4 | port moresby
# Processing Record 38 of Set 4 | cherskiy
# Processing Record 39 of Set 4 | marsa matruh
# Processing Record 40 of Set 4 | gornyak
# Processing Record 41 of Set 4 | lompoc
# Processing Record 42 of Set 4 | mount isa
# Processing Record 43 of Set 4 | tukan
# Processing Record 44 of Set 4 | balabac
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | sambava
# Processing Record 48 of Set 4 | matagami
# Processing Record 49 of Set 4 | atambua
# Processing Record 50 of Set 4 | ahipara
# Processing Record 1 of Set 5 | araouane
# Processing Record 2 of Set 5 | morondava
# Processing Record 3 of Set 5 | cayenne
# Processing Record 4 of Set 5 | irbeyskoye
# Processing Record 5 of Set 5 | nuevo progreso
# Processing Record 6 of Set 5 | vanimo
# Processing Record 7 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 5 | bassila
# Processing Record 9 of Set 5 | khatanga
# Processing Record 10 of Set 5 | klaksvik
# Processing Record 11 of Set 5 | buraydah
# Processing Record 12 of Set 5 | odweyne
# Processing Record 13 of Set 5 | krasnoarmeysk
# Processing Record 14 of Set 5 | ballina
# Processing Record 15 of Set 5 | aporawan
# City not found. Skipping...
# Processing Record 16 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 5 | muisne
# Processing Record 18 of Set 5 | dingle
# Processing Record 19 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 5 | inirida
# Processing Record 21 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 5 | kitimat
# Processing Record 24 of Set 5 | kidal
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | bambous virieux
# Processing Record 27 of Set 5 | monrovia
# Processing Record 28 of Set 5 | henties bay
# Processing Record 29 of Set 5 | ayagoz
# Processing Record 30 of Set 5 | fare
# Processing Record 31 of Set 5 | barrow
# Processing Record 32 of Set 5 | yumen
# Processing Record 33 of Set 5 | mezen
# Processing Record 34 of Set 5 | alofi
# Processing Record 35 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 5 | guerrero negro
# Processing Record 37 of Set 5 | kupang
# Processing Record 38 of Set 5 | vestmannaeyjar
# Processing Record 39 of Set 5 | pingliang
# Processing Record 40 of Set 5 | noumea
# Processing Record 41 of Set 5 | kununurra
# Processing Record 42 of Set 5 | belmonte
# Processing Record 43 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 5 | touros
# Processing Record 45 of Set 5 | zarate
# Processing Record 46 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 5 | makat
# Processing Record 48 of Set 5 | baykit
# Processing Record 49 of Set 5 | naifaru
# Processing Record 50 of Set 5 | peniche
# Processing Record 1 of Set 6 | imaculada
# Processing Record 2 of Set 6 | carnarvon
# Processing Record 3 of Set 6 | joao pinheiro
# Processing Record 4 of Set 6 | vredendal
# Processing Record 5 of Set 6 | viransehir
# Processing Record 6 of Set 6 | sioux lookout
# Processing Record 7 of Set 6 | labuhan
# Processing Record 8 of Set 6 | nazarovo
# Processing Record 9 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 6 | ilulissat
# Processing Record 11 of Set 6 | orange cove
# Processing Record 12 of Set 6 | praia da vitoria
# Processing Record 13 of Set 6 | akyab
# Processing Record 14 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 15 of Set 6 | daru
# Processing Record 16 of Set 6 | erzin
# Processing Record 17 of Set 6 | fairbanks
# Processing Record 18 of Set 6 | severomuysk
# Processing Record 19 of Set 6 | honningsvag
# Processing Record 20 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 6 | san patricio
# Processing Record 22 of Set 6 | yulara
# Processing Record 23 of Set 6 | brae
# Processing Record 24 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 25 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 6 | port lincoln
# Processing Record 27 of Set 6 | chaiyaphum
# Processing Record 28 of Set 6 | caramay
# Processing Record 29 of Set 6 | ambulu
# Processing Record 30 of Set 6 | saint george
# Processing Record 31 of Set 6 | lukovetskiy
# Processing Record 32 of Set 6 | puerto del rosario
# Processing Record 33 of Set 6 | goundi
# Processing Record 34 of Set 6 | toora-khem
# Processing Record 35 of Set 6 | verkhnevilyuysk
# Processing Record 36 of Set 6 | ust-maya
# Processing Record 37 of Set 6 | biltine
# Processing Record 38 of Set 6 | magdagachi
# Processing Record 39 of Set 6 | lata
# Processing Record 40 of Set 6 | farafangana
# Processing Record 41 of Set 6 | oranjemund
# Processing Record 42 of Set 6 | zaysan
# Processing Record 43 of Set 6 | san rafael
# Processing Record 44 of Set 6 | te anau
# Processing Record 45 of Set 6 | elizabeth city
# Processing Record 46 of Set 6 | seymchan
# Processing Record 47 of Set 6 | overath
# Processing Record 48 of Set 6 | los santos
# Processing Record 49 of Set 6 | moranbah
# Processing Record 50 of Set 6 | bykov
# Processing Record 1 of Set 7 | aitape
# Processing Record 2 of Set 7 | salinopolis
# Processing Record 3 of Set 7 | sibolga
# Processing Record 4 of Set 7 | gravelbourg
# Processing Record 5 of Set 7 | cepu
# Processing Record 6 of Set 7 | rafraf
# Processing Record 7 of Set 7 | gumdag
# Processing Record 8 of Set 7 | kangaatsiaq
# Processing Record 9 of Set 7 | bouca
# Processing Record 10 of Set 7 | krutikha
# Processing Record 11 of Set 7 | rio gallegos
# Processing Record 12 of Set 7 | collie
# Processing Record 13 of Set 7 | high level
# Processing Record 14 of Set 7 | yakeshi
# Processing Record 15 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 7 | bure
# Processing Record 18 of Set 7 | sharjah
# Processing Record 19 of Set 7 | vallenar
# Processing Record 20 of Set 7 | paita
# Processing Record 21 of Set 7 | copiapo
# Processing Record 22 of Set 7 | toyooka
# Processing Record 23 of Set 7 | san cristobal
# Processing Record 24 of Set 7 | bonavista
# Processing Record 25 of Set 7 | marzuq
# Processing Record 26 of Set 7 | stanger
# Processing Record 27 of Set 7 | mayo
# Processing Record 28 of Set 7 | sobolevo
# Processing Record 29 of Set 7 | summerville
# Processing Record 30 of Set 7 | port macquarie
# Processing Record 31 of Set 7 | barra do garcas
# Processing Record 32 of Set 7 | khanino
# Processing Record 33 of Set 7 | ahuimanu
# Processing Record 34 of Set 7 | annau
# Processing Record 35 of Set 7 | oranjestad
# Processing Record 36 of Set 7 | vao
# Processing Record 37 of Set 7 | laredo
# Processing Record 38 of Set 7 | waipawa
# Processing Record 39 of Set 7 | parry sound
# Processing Record 40 of Set 7 | namibe
# Processing Record 41 of Set 7 | ecoporanga
# Processing Record 42 of Set 7 | porto velho
# Processing Record 43 of Set 7 | grindavik
# Processing Record 44 of Set 7 | senmonorom
# City not found. Skipping...
# Processing Record 45 of Set 7 | hirado
# Processing Record 46 of Set 7 | lokoja
# Processing Record 47 of Set 7 | hervey bay
# Processing Record 48 of Set 7 | bondo
# Processing Record 49 of Set 7 | buala
# Processing Record 50 of Set 7 | brzesko
# Processing Record 1 of Set 8 | turukhansk
# Processing Record 2 of Set 8 | tanjong karang
# City not found. Skipping...
# Processing Record 3 of Set 8 | zhuanghe
# Processing Record 4 of Set 8 | hasaki
# Processing Record 5 of Set 8 | eyl
# Processing Record 6 of Set 8 | carballo
# Processing Record 7 of Set 8 | tyup
# Processing Record 8 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 9 of Set 8 | aykhal
# Processing Record 10 of Set 8 | nabire
# Processing Record 11 of Set 8 | marsabit
# Processing Record 12 of Set 8 | novo oriente
# Processing Record 13 of Set 8 | corn island
# Processing Record 14 of Set 8 | ambilobe
# Processing Record 15 of Set 8 | lavrentiya
# Processing Record 16 of Set 8 | tongchuan
# Processing Record 17 of Set 8 | kerman
# Processing Record 18 of Set 8 | saint-georges
# Processing Record 19 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 8 | mersing
# Processing Record 21 of Set 8 | zhezkazgan
# Processing Record 22 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 23 of Set 8 | segezha
# Processing Record 24 of Set 8 | konotop
# Processing Record 25 of Set 8 | baruun-urt
# Processing Record 26 of Set 8 | puerto leguizamo
# Processing Record 27 of Set 8 | hay river
# Processing Record 28 of Set 8 | portales
# Processing Record 29 of Set 8 | port hedland
# Processing Record 30 of Set 8 | shingu
# Processing Record 31 of Set 8 | bilma
# Processing Record 32 of Set 8 | san lorenzo
# Processing Record 33 of Set 8 | zima
# Processing Record 34 of Set 8 | villa carlos paz
# Processing Record 35 of Set 8 | kenda
# Processing Record 36 of Set 8 | hithadhoo
# Processing Record 37 of Set 8 | glushkovo
# Processing Record 38 of Set 8 | santa fe
# Processing Record 39 of Set 8 | kargil
# Processing Record 40 of Set 8 | snasa
# Processing Record 41 of Set 8 | snyder
# Processing Record 42 of Set 8 | palana
# Processing Record 43 of Set 8 | xam nua
# Processing Record 44 of Set 8 | togur
# Processing Record 45 of Set 8 | meadow lake
# Processing Record 46 of Set 8 | ouesso
# Processing Record 47 of Set 8 | ust-nera
# Processing Record 48 of Set 8 | izmalkovo
# Processing Record 49 of Set 8 | soyo
# Processing Record 50 of Set 8 | nantucket
# Processing Record 1 of Set 9 | belyy yar
# Processing Record 2 of Set 9 | flinders
# Processing Record 3 of Set 9 | tiznit
# Processing Record 4 of Set 9 | berlevag
# Processing Record 5 of Set 9 | conceicao do araguaia
# Processing Record 6 of Set 9 | bud
# Processing Record 7 of Set 9 | stromness
# Processing Record 8 of Set 9 | constantine
# Processing Record 9 of Set 9 | belaya gora
# Processing Record 10 of Set 9 | hualmay
# Processing Record 11 of Set 9 | san jose
# Processing Record 12 of Set 9 | oskemen
# Processing Record 13 of Set 9 | comodoro rivadavia
# Processing Record 14 of Set 9 | nishihara
# Processing Record 15 of Set 9 | bogorodskoye
# Processing Record 16 of Set 9 | cam ranh
# Processing Record 17 of Set 9 | avera
# Processing Record 18 of Set 9 | antsohihy
# Processing Record 19 of Set 9 | rosario
# Processing Record 20 of Set 9 | codrington
# Processing Record 21 of Set 9 | khorramshahr
# Processing Record 22 of Set 9 | anito
# Processing Record 23 of Set 9 | balaipungut
# Processing Record 24 of Set 9 | kamenka
# Processing Record 25 of Set 9 | taoudenni
# Processing Record 26 of Set 9 | tuatapere
# Processing Record 27 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 28 of Set 9 | priiskovyy
# Processing Record 29 of Set 9 | morehead
# Processing Record 30 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 9 | talnakh
# Processing Record 33 of Set 9 | jaque
# Processing Record 34 of Set 9 | nanortalik
# Processing Record 35 of Set 9 | pereira
# Processing Record 36 of Set 9 | kichera
# Processing Record 37 of Set 9 | vigia del fuerte
# Processing Record 38 of Set 9 | jumla
# Processing Record 39 of Set 9 | lodja
# Processing Record 40 of Set 9 | roebourne
# Processing Record 41 of Set 9 | severo-kurilsk
# Processing Record 42 of Set 9 | port blair
# Processing Record 43 of Set 9 | tateyama
# Processing Record 44 of Set 9 | kysyl-syr
# Processing Record 45 of Set 9 | lorengau
# Processing Record 46 of Set 9 | ashland
# Processing Record 47 of Set 9 | porto walter
# Processing Record 48 of Set 9 | dunedin
# Processing Record 49 of Set 9 | ondjiva
# Processing Record 50 of Set 9 | maniitsoq
# Processing Record 1 of Set 10 | lusambo
# Processing Record 2 of Set 10 | moree
# Processing Record 3 of Set 10 | nyurba
# Processing Record 4 of Set 10 | los llanos de aridane
# Processing Record 5 of Set 10 | dzaoudzi
# Processing Record 6 of Set 10 | shizuishan
# Processing Record 7 of Set 10 | andros town
# Processing Record 8 of Set 10 | adjumani
# Processing Record 9 of Set 10 | inta
# Processing Record 10 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 10 | la ronge
# Processing Record 12 of Set 10 | tezu
# Processing Record 13 of Set 10 | tilichiki
# Processing Record 14 of Set 10 | sept-iles
# Processing Record 15 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 10 | srednekolymsk
# Processing Record 17 of Set 10 | neiafu
# Processing Record 18 of Set 10 | san rafael del sur
# Processing Record 19 of Set 10 | morro bay
# Processing Record 20 of Set 10 | iquique
# Processing Record 21 of Set 10 | sinnamary
# Processing Record 22 of Set 10 | north bend
# Processing Record 23 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 24 of Set 10 | acari
# Processing Record 25 of Set 10 | grand forks
# Processing Record 26 of Set 10 | pucara
# Processing Record 27 of Set 10 | boa vista
# Processing Record 28 of Set 10 | muswellbrook
# Processing Record 29 of Set 10 | ancud
# Processing Record 30 of Set 10 | bela
# Processing Record 31 of Set 10 | kahului
# Processing Record 32 of Set 10 | ayan
# Processing Record 33 of Set 10 | aloleng
# Processing Record 34 of Set 10 | rivadavia
# Processing Record 35 of Set 10 | samarai
# Processing Record 36 of Set 10 | fortuna
# Processing Record 37 of Set 10 | severnyy
# Processing Record 38 of Set 10 | wuwei
# Processing Record 39 of Set 10 | nelson bay
# Processing Record 40 of Set 10 | sistranda
# Processing Record 41 of Set 10 | henderson
# Processing Record 42 of Set 10 | juneau
# Processing Record 43 of Set 10 | mackay
# Processing Record 44 of Set 10 | barghat
# Processing Record 45 of Set 10 | alexandria
# Processing Record 46 of Set 10 | fiditi
# Processing Record 47 of Set 10 | bubaque
# Processing Record 48 of Set 10 | makakilo city
# Processing Record 49 of Set 10 | musoma
# Processing Record 50 of Set 10 | mareeba
# Processing Record 1 of Set 11 | nome
# Processing Record 2 of Set 11 | svetlyy
# Processing Record 3 of Set 11 | anadyr
# Processing Record 4 of Set 11 | claveria
# Processing Record 5 of Set 11 | galesong
# Processing Record 6 of Set 11 | umm lajj
# Processing Record 7 of Set 11 | ochamchira
# Processing Record 8 of Set 11 | riaba
# City not found. Skipping...
# Processing Record 9 of Set 11 | naze
# Processing Record 10 of Set 11 | ponta do sol
# Processing Record 11 of Set 11 | padang
# Processing Record 12 of Set 11 | iskateley
# Processing Record 13 of Set 11 | deputatskiy
# Processing Record 14 of Set 11 | pitanga
# Processing Record 15 of Set 11 | istok
# Processing Record 16 of Set 11 | katangli
# Processing Record 17 of Set 11 | burns lake
# Processing Record 18 of Set 11 | marakkanam
# Processing Record 19 of Set 11 | guaymas
# Processing Record 20 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 11 | college
# Processing Record 22 of Set 11 | chambas
# Processing Record 23 of Set 11 | kabalo
# Processing Record 24 of Set 11 | lamu
# Processing Record 25 of Set 11 | miyako
# Processing Record 26 of Set 11 | correntina
# Processing Record 27 of Set 11 | sringeri
# Processing Record 28 of Set 11 | paamiut
# Processing Record 29 of Set 11 | ngunguru
# Processing Record 30 of Set 11 | wukari
# Processing Record 31 of Set 11 | albury
# Processing Record 32 of Set 11 | karaton
# Processing Record 33 of Set 11 | bodden town
# Processing Record 34 of Set 11 | los andes
# Processing Record 35 of Set 11 | moyale
# Processing Record 36 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 11 | rio grande
# Processing Record 38 of Set 11 | jacareacanga
# Processing Record 39 of Set 11 | grand gaube
# Processing Record 40 of Set 11 | uzunkopru
# City not found. Skipping...
# Processing Record 41 of Set 11 | imbituba
# Processing Record 42 of Set 11 | karpathos
# Processing Record 43 of Set 11 | hami
# Processing Record 44 of Set 11 | manoel urbano
# Processing Record 45 of Set 11 | vila
# Processing Record 46 of Set 11 | haines junction
# Processing Record 47 of Set 11 | waitati
# Processing Record 48 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 11 | shaowu
# Processing Record 50 of Set 11 | ornskoldsvik
# Processing Record 1 of Set 12 | qandala
# Processing Record 2 of Set 12 | yeppoon
# Processing Record 3 of Set 12 | krupanj
# Processing Record 4 of Set 12 | scanteia
# Processing Record 5 of Set 12 | bilibino
# Processing Record 6 of Set 12 | whitehorse
# Processing Record 7 of Set 12 | verkhnyaya inta
# Processing Record 8 of Set 12 | teya
# Processing Record 9 of Set 12 | portland
# Processing Record 10 of Set 12 | charters towers
# Processing Record 11 of Set 12 | ulcinj
# Processing Record 12 of Set 12 | uyemskiy
# Processing Record 13 of Set 12 | nuuk
# Processing Record 14 of Set 12 | pangnirtung
# Processing Record 15 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 16 of Set 12 | macapa
# Processing Record 17 of Set 12 | sapapalii
# City not found. Skipping...
# Processing Record 18 of Set 12 | troitskoye
# Processing Record 19 of Set 12 | yasnyy
# Processing Record 20 of Set 12 | larsnes
# Processing Record 21 of Set 12 | shimoda
# Processing Record 22 of Set 12 | creel
# Processing Record 23 of Set 12 | pringsewu
# Processing Record 24 of Set 12 | okhotsk
# Processing Record 25 of Set 12 | general roca
# Processing Record 26 of Set 12 | liverpool
# Processing Record 27 of Set 12 | reinbek
# Processing Record 28 of Set 12 | emerald
# Processing Record 29 of Set 12 | pointe michel
# Processing Record 30 of Set 12 | harper
# Processing Record 31 of Set 12 | norman wells
# Processing Record 32 of Set 12 | banda aceh
# Processing Record 33 of Set 12 | kampong thum
# Processing Record 34 of Set 12 | hovd
# Processing Record 35 of Set 12 | dulag
# Processing Record 36 of Set 12 | lojt kirkeby
# Processing Record 37 of Set 12 | salalah
# Processing Record 38 of Set 12 | ruteng
# Processing Record 39 of Set 12 | santa barbara
# Processing Record 40 of Set 12 | abu samrah
# Processing Record 41 of Set 12 | tura
# Processing Record 42 of Set 12 | martapura
# Processing Record 43 of Set 12 | zelenoborskiy
# Processing Record 44 of Set 12 | springbok
# Processing Record 45 of Set 12 | batsfjord
# Processing Record 46 of Set 12 | alghero
# Processing Record 47 of Set 12 | mount hagen
# Processing Record 48 of Set 12 | bajil
# Processing Record 49 of Set 12 | bismarck
# Processing Record 50 of Set 12 | kolosovka
# Processing Record 1 of Set 13 | antofagasta
# Processing Record 2 of Set 13 | caxito
# Processing Record 3 of Set 13 | the pas
# Processing Record 4 of Set 13 | yining
# Processing Record 5 of Set 13 | yatou
# Processing Record 6 of Set 13 | polunochnoye
# Processing Record 7 of Set 13 | kaeo
# Processing Record 8 of Set 13 | grand-santi
# Processing Record 9 of Set 13 | lindas
# Processing Record 10 of Set 13 | cap-aux-meules
# Processing Record 11 of Set 13 | sindor
# Processing Record 12 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 13 of Set 13 | teguise
# Processing Record 14 of Set 13 | santa maria
# Processing Record 15 of Set 13 | kozhva
# Processing Record 16 of Set 13 | muroto
# Processing Record 17 of Set 13 | beatrice
# Processing Record 18 of Set 13 | jardim de piranhas
# Processing Record 19 of Set 13 | leningradskiy
# Processing Record 20 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 13 | georgiyevka
# Processing Record 22 of Set 13 | tutoia
# Processing Record 23 of Set 13 | kehtna
# Processing Record 24 of Set 13 | madimba
# Processing Record 25 of Set 13 | darnah
# Processing Record 26 of Set 13 | romny
# Processing Record 27 of Set 13 | beachwood
# Processing Record 28 of Set 13 | kutum
# Processing Record 29 of Set 13 | raudeberg
# Processing Record 30 of Set 13 | pushchino
# Processing Record 31 of Set 13 | sarakhs
# Processing Record 32 of Set 13 | pontes e lacerda
# Processing Record 33 of Set 13 | anthia
# City not found. Skipping...
# Processing Record 34 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 35 of Set 13 | kautokeino
# Processing Record 36 of Set 13 | husavik
# Processing Record 37 of Set 13 | bazarnyye mataki
# Processing Record 38 of Set 13 | cape elizabeth
# City not found. Skipping...
# Processing Record 39 of Set 13 | aragarcas
# Processing Record 40 of Set 13 | coihaique
# Processing Record 41 of Set 13 | nizhniy baskunchak
# Processing Record 42 of Set 13 | bose
# Processing Record 43 of Set 13 | hofn
# Processing Record 44 of Set 13 | hereford
# Processing Record 45 of Set 13 | tocopilla
# Processing Record 46 of Set 13 | shelburne
# Processing Record 47 of Set 13 | jalu
# Processing Record 48 of Set 13 | maumere
# Processing Record 49 of Set 13 | yeltsovka
# City not found. Skipping...
# Processing Record 50 of Set 13 | rafaela
# Processing Record 1 of Set 14 | beysehir
# Processing Record 2 of Set 14 | aksu
# Processing Record 3 of Set 14 | griffith
# Processing Record 4 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 14 | mehamn
# Processing Record 6 of Set 14 | manado
# Processing Record 7 of Set 14 | barkot
# Processing Record 8 of Set 14 | meulaboh
# Processing Record 9 of Set 14 | sairang
# Processing Record 10 of Set 14 | urumqi
# Processing Record 11 of Set 14 | ozernovskiy
# Processing Record 12 of Set 14 | freeport
# Processing Record 13 of Set 14 | cozumel
# Processing Record 14 of Set 14 | sakakah
# Processing Record 15 of Set 14 | van
# Processing Record 16 of Set 14 | bundaberg
# Processing Record 17 of Set 14 | santa rosa
# Processing Record 18 of Set 14 | kalaleh
# Processing Record 19 of Set 14 | iberia
# Processing Record 20 of Set 14 | jardim
# Processing Record 21 of Set 14 | igrim
# Processing Record 22 of Set 14 | hohhot
# Processing Record 23 of Set 14 | aklavik
# Processing Record 24 of Set 14 | nakamura
# Processing Record 25 of Set 14 | yayva
# Processing Record 26 of Set 14 | matamoros
# Processing Record 27 of Set 14 | pierre
# Processing Record 28 of Set 14 | weligama
# Processing Record 29 of Set 14 | sarkand
# Processing Record 30 of Set 14 | qarqin
# Processing Record 31 of Set 14 | iracoubo
# Processing Record 32 of Set 14 | mount gambier
# Processing Record 33 of Set 14 | omboue
# Processing Record 34 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 14 | mamakan
# Processing Record 36 of Set 14 | pasir gudang
# Processing Record 37 of Set 14 | san policarpo
# Processing Record 38 of Set 14 | minnedosa
# Processing Record 39 of Set 14 | luena
# Processing Record 40 of Set 14 | veraval
# Processing Record 41 of Set 14 | rzhyshchiv
# Processing Record 42 of Set 14 | soligalich
# Processing Record 43 of Set 14 | vondrozo
# Processing Record 44 of Set 14 | hit
# Processing Record 45 of Set 14 | turayf
# Processing Record 46 of Set 14 | sisophon
# Processing Record 47 of Set 14 | diapaga
# Processing Record 48 of Set 14 | luba
# Processing Record 49 of Set 14 | rocha
# Processing Record 50 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 15 | boueni
# Processing Record 2 of Set 15 | arkhangelsk
# Processing Record 3 of Set 15 | gobabis
# Processing Record 4 of Set 15 | shasta lake
# Processing Record 5 of Set 15 | ugoofaaru
# Processing Record 6 of Set 15 | lerici
# Processing Record 7 of Set 15 | hobbs
# Processing Record 8 of Set 15 | trairi
# Processing Record 9 of Set 15 | mildura
# Processing Record 10 of Set 15 | ishigaki
# Processing Record 11 of Set 15 | zeya
# Processing Record 12 of Set 15 | karlivka
# Processing Record 13 of Set 15 | vila velha
# Processing Record 14 of Set 15 | sao joao da barra
# Processing Record 15 of Set 15 | inuvik
# Processing Record 16 of Set 15 | ternate
# Processing Record 17 of Set 15 | matias romero
# Processing Record 18 of Set 15 | rabo de peixe
# Processing Record 19 of Set 15 | herat
# Processing Record 20 of Set 15 | volokolamsk
# Processing Record 21 of Set 15 | santarem
# Processing Record 22 of Set 15 | simao
# Processing Record 23 of Set 15 | siparia
# Processing Record 24 of Set 15 | dzhebariki-khaya
# Processing Record 25 of Set 15 | calera
# Processing Record 26 of Set 15 | puksoozero
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Seoul',
#   'Lat': 37.5683,
#   'Lng': 126.9778,
#   'Max Temp': 45.84,
#   'Humidity': 51,
#   'Cloudiness': 27,
#   'Wind Speed': 1.86,
#   'Country': 'KR',
#   'Date': '2021-10-24 22:09:14'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 49.89,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 3.11,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:07:08'},
#  {'City': 'Bonthe',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 78.22,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.3,
#   'Country': 'SL',
#   'Date': '2021-10-24 22:10:11'},
#  {'City': 'Port Hawkesbury',
#   'Lat': 45.6169,
#   'Lng': -61.3485,
#   'Max Temp': 48.58,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 8.01,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:10:11'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 45.91,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-10-24 22:09:20'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 55.04,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 9.91,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:10:12'},
#  {'City': 'Waingapu',
#   'Lat': -9.6567,
#   'Lng': 120.2641,
#   'Max Temp': 78.64,
#   'Humidity': 84,
#   'Cloudiness': 79,
#   'Wind Speed': 1.48,
#   'Country': 'ID',
#   'Date': '2021-10-24 22:05:15'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 74.48,
#   'Humidity': 83,
#   'Cloudiness': 47,
#   'Wind Speed': 16.37,
#   'Country': 'RE',
#   'Date': '2021-10-24 22:10:13'},
#  {'City': 'Tynda',
#   'Lat': 55.1667,
#   'Lng': 124.7167,
#   'Max Temp': 28.67,
#   'Humidity': 94,
#   'Cloudiness': 39,
#   'Wind Speed': 0.27,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:13'},
#  {'City': 'Labytnangi',
#   'Lat': 66.6572,
#   'Lng': 66.4183,
#   'Max Temp': 17.24,
#   'Humidity': 89,
#   'Cloudiness': 84,
#   'Wind Speed': 6.73,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:13'},
#  {'City': 'Kangaba',
#   'Lat': 11.9333,
#   'Lng': -8.4167,
#   'Max Temp': 79.75,
#   'Humidity': 65,
#   'Cloudiness': 78,
#   'Wind Speed': 2.84,
#   'Country': 'ML',
#   'Date': '2021-10-24 22:10:14'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 77.05,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'CK',
#   'Date': '2021-10-24 22:10:14'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 32.16,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 45.54,
#   'Country': 'GL',
#   'Date': '2021-10-24 22:05:25'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 70.25,
#   'Humidity': 73,
#   'Cloudiness': 37,
#   'Wind Speed': 1.99,
#   'Country': 'HK',
#   'Date': '2021-10-24 22:08:40'},
#  {'City': 'Itaituba',
#   'Lat': -4.2761,
#   'Lng': -55.9836,
#   'Max Temp': 84.65,
#   'Humidity': 61,
#   'Cloudiness': 99,
#   'Wind Speed': 2.75,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:10:15'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.92,
#   'Humidity': 73,
#   'Cloudiness': 2,
#   'Wind Speed': 17.36,
#   'Country': 'PF',
#   'Date': '2021-10-24 22:10:16'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 49.89,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-10-24 22:05:45'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 44.71,
#   'Humidity': 42,
#   'Cloudiness': 40,
#   'Wind Speed': 32.21,
#   'Country': 'CL',
#   'Date': '2021-10-24 22:08:10'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 35.26,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Country': 'AR',
#   'Date': '2021-10-24 22:10:17'},
#  {'City': 'Mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 79.43,
#   'Humidity': 81,
#   'Cloudiness': 45,
#   'Wind Speed': 13.76,
#   'Country': 'SO',
#   'Date': '2021-10-24 22:10:17'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 78.53,
#   'Humidity': 72,
#   'Cloudiness': 49,
#   'Wind Speed': 11.18,
#   'Country': 'CV',
#   'Date': '2021-10-24 22:09:39'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.96,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'TO',
#   'Date': '2021-10-24 22:10:17'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 24.91,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:09:24'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 59.34,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 3.2,
#   'Country': 'NZ',
#   'Date': '2021-10-24 22:10:18'},
#  {'City': 'Iwaki',
#   'Lat': 37.05,
#   'Lng': 140.8833,
#   'Max Temp': 52.23,
#   'Humidity': 70,
#   'Cloudiness': 7,
#   'Wind Speed': 4.32,
#   'Country': 'JP',
#   'Date': '2021-10-24 22:10:19'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 57.88,
#   'Humidity': 89,
#   'Cloudiness': 94,
#   'Wind Speed': 1.99,
#   'Country': 'GB',
#   'Date': '2021-10-24 22:10:19'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 74.73,
#   'Humidity': 76,
#   'Cloudiness': 43,
#   'Wind Speed': 16.53,
#   'Country': 'PF',
#   'Date': '2021-10-24 22:08:53'},
#  {'City': 'Moba',
#   'Lat': 33.2288,
#   'Lng': 105.0179,
#   'Max Temp': 44.8,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'CN',
#   'Date': '2021-10-24 22:10:20'},
#  {'City': 'Vilyuysk',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': 30.63,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.87,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:20'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 51.39,
#   'Humidity': 98,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-10-24 22:08:48'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 52.02,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 5.01,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:10:21'},
#  {'City': 'Saryg-Sep',
#   'Lat': 51.5,
#   'Lng': 95.6,
#   'Max Temp': 30.42,
#   'Humidity': 71,
#   'Cloudiness': 94,
#   'Wind Speed': 1.59,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:22'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -7.29,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:06:31'},
#  {'City': 'Vitim',
#   'Lat': 59.4511,
#   'Lng': 112.5578,
#   'Max Temp': 36.32,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 11.16,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:23'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 76.28,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 15.19,
#   'Country': 'PF',
#   'Date': '2021-10-24 22:08:52'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.76,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 10.85,
#   'Country': 'EC',
#   'Date': '2021-10-24 22:10:23'},
#  {'City': 'Pyay',
#   'Lat': 18.8167,
#   'Lng': 95.2167,
#   'Max Temp': 73.44,
#   'Humidity': 95,
#   'Cloudiness': 96,
#   'Wind Speed': 1.83,
#   'Country': 'MM',
#   'Date': '2021-10-24 22:10:24'},
#  {'City': 'Vilanova Del Cami',
#   'Lat': 41.5717,
#   'Lng': 1.6375,
#   'Max Temp': 60.78,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 2.15,
#   'Country': 'ES',
#   'Date': '2021-10-24 22:10:24'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 60.13,
#   'Humidity': 76,
#   'Cloudiness': 48,
#   'Wind Speed': 11.05,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:07:29'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 85.28,
#   'Humidity': 83,
#   'Cloudiness': 39,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-10-24 22:08:34'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 59.07,
#   'Humidity': 74,
#   'Cloudiness': 12,
#   'Wind Speed': 11.01,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:10:25'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 59.34,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:07:24'},
#  {'City': 'Alvaraes',
#   'Lat': -3.2208,
#   'Lng': -64.8042,
#   'Max Temp': 93.07,
#   'Humidity': 84,
#   'Cloudiness': 69,
#   'Wind Speed': 4.47,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:09:20'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 17.44,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'SJ',
#   'Date': '2021-10-24 22:08:34'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 77.36,
#   'Humidity': 86,
#   'Cloudiness': 2,
#   'Wind Speed': 10.45,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:10:26'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 55.2,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-10-24 22:10:26'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 58.75,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 16.13,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:10:27'},
#  {'City': 'Cravo Norte',
#   'Lat': 6.3017,
#   'Lng': -70.2041,
#   'Max Temp': 84.51,
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 7.96,
#   'Country': 'CO',
#   'Date': '2021-10-24 22:10:27'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 74.41,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2021-10-24 22:09:09'},
#  {'City': 'Lakes Entrance',
#   'Lat': -37.8811,
#   'Lng': 147.981,
#   'Max Temp': 54.16,
#   'Humidity': 71,
#   'Cloudiness': 88,
#   'Wind Speed': 7.7,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:10:28'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 52.11,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 3.47,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:09:17'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 32.22,
#   'Humidity': 49,
#   'Cloudiness': 98,
#   'Wind Speed': 6.26,
#   'Country': 'GL',
#   'Date': '2021-10-24 22:10:28'},
#  {'City': 'North Platte',
#   'Lat': 41.1239,
#   'Lng': -100.7654,
#   'Max Temp': 62.49,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Date': '2021-10-24 22:10:29'},
#  {'City': 'Migori',
#   'Lat': -1.0634,
#   'Lng': 34.4731,
#   'Max Temp': 65.34,
#   'Humidity': 73,
#   'Cloudiness': 47,
#   'Wind Speed': 4.83,
#   'Country': 'KE',
#   'Date': '2021-10-24 22:10:29'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 53.62,
#   'Humidity': 72,
#   'Cloudiness': 94,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': '2021-10-24 22:06:34'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 54.43,
#   'Humidity': 90,
#   'Cloudiness': 96,
#   'Wind Speed': 4.32,
#   'Country': 'NZ',
#   'Date': '2021-10-24 22:10:30'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 54.86,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 14.41,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:07:23'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 75.36,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'MU',
#   'Date': '2021-10-24 22:10:30'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 37.96,
#   'Humidity': 77,
#   'Cloudiness': 7,
#   'Wind Speed': 2.51,
#   'Country': 'RO',
#   'Date': '2021-10-24 22:05:58'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 49.28,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.21,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:10:31'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 6.39,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.03,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:31'},
#  {'City': 'Kibaya',
#   'Lat': -5.3,
#   'Lng': 36.5667,
#   'Max Temp': 63.54,
#   'Humidity': 69,
#   'Cloudiness': 8,
#   'Wind Speed': 5.46,
#   'Country': 'TZ',
#   'Date': '2021-10-24 22:10:32'},
#  {'City': 'Pokhara',
#   'Lat': 28.2333,
#   'Lng': 83.9833,
#   'Max Temp': 59.97,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 6.53,
#   'Country': 'NP',
#   'Date': '2021-10-24 22:10:32'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 84.18,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Date': '2021-10-24 22:10:33'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 29.7,
#   'Humidity': 92,
#   'Cloudiness': 82,
#   'Wind Speed': 5.99,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:10:33'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.48,
#   'Humidity': 72,
#   'Cloudiness': 48,
#   'Wind Speed': 3.24,
#   'Country': 'KI',
#   'Date': '2021-10-24 22:10:34'},
#  {'City': 'Ventspils',
#   'Lat': 57.3894,
#   'Lng': 21.5606,
#   'Max Temp': 49.93,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'LV',
#   'Date': '2021-10-24 22:10:34'},
#  {'City': 'Wakkanai',
#   'Lat': 45.4094,
#   'Lng': 141.6739,
#   'Max Temp': 55.4,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 16.67,
#   'Country': 'JP',
#   'Date': '2021-10-24 22:10:35'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 55.67,
#   'Humidity': 85,
#   'Cloudiness': 12,
#   'Wind Speed': 8.57,
#   'Country': 'CL',
#   'Date': '2021-10-24 22:08:53'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 75.25,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'MU',
#   'Date': '2021-10-24 22:08:47'},
#  {'City': 'Eureka',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Max Temp': 59.63,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'US',
#   'Date': '2021-10-24 22:10:35'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 69.82,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 3.11,
#   'Country': 'IL',
#   'Date': '2021-10-24 22:10:36'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 63.37,
#   'Humidity': 75,
#   'Cloudiness': 98,
#   'Wind Speed': 1.28,
#   'Country': 'TL',
#   'Date': '2021-10-24 22:07:48'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 63.01,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'PT',
#   'Date': '2021-10-24 22:07:36'},
#  {'City': 'Tevaitoa',
#   'Lat': -16.7833,
#   'Lng': -151.5,
#   'Max Temp': 76.19,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 11.27,
#   'Country': 'PF',
#   'Date': '2021-10-24 22:10:37'},
#  {'City': 'Andenes',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 37.38,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'NO',
#   'Date': '2021-10-24 22:10:37'},
#  {'City': 'Sligo',
#   'Lat': 54.2697,
#   'Lng': -8.4694,
#   'Max Temp': 48.02,
#   'Humidity': 88,
#   'Cloudiness': 26,
#   'Wind Speed': 11.92,
#   'Country': 'IE',
#   'Date': '2021-10-24 22:10:38'},
#  {'City': 'Moron',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 74.95,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 4.9,
#   'Country': 'AR',
#   'Date': '2021-10-24 22:10:38'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 82.94,
#   'Humidity': 71,
#   'Cloudiness': 91,
#   'Wind Speed': 5.91,
#   'Country': 'PG',
#   'Date': '2021-10-24 22:09:14'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 56.71,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 3.09,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:10:39'},
#  {'City': 'Mumford',
#   'Lat': 5.2618,
#   'Lng': -0.759,
#   'Max Temp': 78.19,
#   'Humidity': 85,
#   'Cloudiness': 33,
#   'Wind Speed': 5.66,
#   'Country': 'GH',
#   'Date': '2021-10-24 22:10:39'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': 24.82,
#   'Humidity': 90,
#   'Cloudiness': 98,
#   'Wind Speed': 21.32,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:40'},
#  {'City': 'Kuala Terengganu',
#   'Lat': 5.3302,
#   'Lng': 103.1408,
#   'Max Temp': 77.23,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 4.16,
#   'Country': 'MY',
#   'Date': '2021-10-24 22:10:40'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 57.11,
#   'Humidity': 63,
#   'Cloudiness': 64,
#   'Wind Speed': 6.91,
#   'Country': 'JP',
#   'Date': '2021-10-24 22:10:40'},
#  {'City': 'Cabedelo',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 79.47,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 8.55,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:07:57'},
#  {'City': 'Osa',
#   'Lat': 57.2829,
#   'Lng': 55.4567,
#   'Max Temp': 37.29,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 8.86,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:41'},
#  {'City': 'Naryan-Mar',
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': 20.19,
#   'Humidity': 97,
#   'Cloudiness': 82,
#   'Wind Speed': 4.76,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:42'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.89,
#   'Humidity': 70,
#   'Cloudiness': 52,
#   'Wind Speed': 10.69,
#   'Country': 'PG',
#   'Date': '2021-10-24 22:07:30'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 26.44,
#   'Humidity': 90,
#   'Cloudiness': 88,
#   'Wind Speed': 3.22,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:10:42'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.13,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.39,
#   'Country': 'ID',
#   'Date': '2021-10-24 22:10:43'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 6.12,
#   'Humidity': 100,
#   'Cloudiness': 74,
#   'Wind Speed': 5.61,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:43'},
#  {'City': 'Tomatlan',
#   'Lat': 19.9333,
#   'Lng': -105.25,
#   'Max Temp': 88.75,
#   'Humidity': 61,
#   'Cloudiness': 86,
#   'Wind Speed': 9.89,
#   'Country': 'MX',
#   'Date': '2021-10-24 22:10:44'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 44.91,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 24.94,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:10:45'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 34.88,
#   'Humidity': 80,
#   'Cloudiness': 85,
#   'Wind Speed': 5.66,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:06:13'},
#  {'City': 'Necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 59.49,
#   'Humidity': 58,
#   'Cloudiness': 6,
#   'Wind Speed': 6.02,
#   'Country': 'AR',
#   'Date': '2021-10-24 22:10:45'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 31.71,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 4.94,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:07:44'},
#  {'City': 'Kristiinankaupunki',
#   'Lat': 62.2743,
#   'Lng': 21.376,
#   'Max Temp': 46.49,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 16.64,
#   'Country': 'FI',
#   'Date': '2021-10-24 22:10:46'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 64.04,
#   'Humidity': 67,
#   'Cloudiness': 84,
#   'Wind Speed': 4.94,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:06:46'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 90.61,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Country': 'MX',
#   'Date': '2021-10-24 22:10:09'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 62.13,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:10:47'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 60.57,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 7.38,
#   'Country': 'UY',
#   'Date': '2021-10-24 22:10:47'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 58.73,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 3.06,
#   'Country': 'NZ',
#   'Date': '2021-10-24 22:06:11'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 55.67,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 11.01,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:10:48'},
#  {'City': 'Awbari',
#   'Lat': 26.5921,
#   'Lng': 12.7805,
#   'Max Temp': 77.04,
#   'Humidity': 32,
#   'Cloudiness': 57,
#   'Wind Speed': 8.93,
#   'Country': 'LY',
#   'Date': '2021-10-24 22:10:49'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 78.31,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 9.48,
#   'Country': 'GA',
#   'Date': '2021-10-24 22:10:49'},
#  {'City': 'Nkhata Bay',
#   'Lat': -11.6066,
#   'Lng': 34.2907,
#   'Max Temp': 78.13,
#   'Humidity': 52,
#   'Cloudiness': 10,
#   'Wind Speed': 4.34,
#   'Country': 'MW',
#   'Date': '2021-10-24 22:10:50'},
#  {'City': 'Joensuu',
#   'Lat': 62.6012,
#   'Lng': 29.7632,
#   'Max Temp': 32.49,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Country': 'FI',
#   'Date': '2021-10-24 22:10:50'},
#  {'City': 'Half Moon Bay',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 64.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 31.07,
#   'Country': 'US',
#   'Date': '2021-10-24 22:10:51'},
#  {'City': 'Sumbe',
#   'Lat': -11.2061,
#   'Lng': 13.8437,
#   'Max Temp': 75.54,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 10.07,
#   'Country': 'AO',
#   'Date': '2021-10-24 22:10:51'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -15.03,
#   'Humidity': 100,
#   'Cloudiness': 64,
#   'Wind Speed': 3.89,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:13'},
#  {'City': 'Redmond',
#   'Lat': 47.674,
#   'Lng': -122.1215,
#   'Max Temp': 54.09,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-10-24 22:10:02'},
#  {'City': 'Taylor',
#   'Lat': 32.3001,
#   'Lng': -99.8337,
#   'Max Temp': 92.93,
#   'Humidity': 17,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-10-24 22:06:03'},
#  {'City': 'Ranfurly',
#   'Lat': -45.1333,
#   'Lng': 170.1,
#   'Max Temp': 56.07,
#   'Humidity': 82,
#   'Cloudiness': 77,
#   'Wind Speed': 1.72,
#   'Country': 'NZ',
#   'Date': '2021-10-24 22:10:52'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 51.66,
#   'Humidity': 60,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:10:53'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 60.62,
#   'Humidity': 73,
#   'Cloudiness': 2,
#   'Wind Speed': 17.4,
#   'Country': 'CL',
#   'Date': '2021-10-24 22:10:53'},
#  {'City': 'Skjervoy',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 34.66,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 23.64,
#   'Country': 'NO',
#   'Date': '2021-10-24 22:10:54'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 66.69,
#   'Humidity': 72,
#   'Cloudiness': 10,
#   'Wind Speed': 9.08,
#   'Country': 'PT',
#   'Date': '2021-10-24 22:10:54'},
#  {'City': 'Ust-Kuyga',
#   'Lat': 70.0167,
#   'Lng': 135.6,
#   'Max Temp': 2.53,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:55'},
#  {'City': 'Bauchi',
#   'Lat': 10.5,
#   'Lng': 10,
#   'Max Temp': 77.56,
#   'Humidity': 45,
#   'Cloudiness': 78,
#   'Wind Speed': 1.79,
#   'Country': 'NG',
#   'Date': '2021-10-24 22:10:55'},
#  {'City': 'Qasigiannguit',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Max Temp': 21.45,
#   'Humidity': 80,
#   'Cloudiness': 97,
#   'Wind Speed': 5.95,
#   'Country': 'GL',
#   'Date': '2021-10-24 22:10:56'},
#  {'City': 'Indiana',
#   'Lat': 40.0003,
#   'Lng': -86.2503,
#   'Max Temp': 63.73,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-10-24 22:10:56'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 59.32,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 3.18,
#   'Country': 'NA',
#   'Date': '2021-10-24 22:10:56'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 77.9,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Date': '2021-10-24 22:10:57'},
#  {'City': 'Petropavlovka',
#   'Lat': 50.6114,
#   'Lng': 105.3196,
#   'Max Temp': 33.89,
#   'Humidity': 64,
#   'Cloudiness': 43,
#   'Wind Speed': 3.71,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:10:57'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 71.49,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 16.31,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:10:58'},
#  {'City': 'Santiago',
#   'Lat': -33.4569,
#   'Lng': -70.6483,
#   'Max Temp': 83.64,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'CL',
#   'Date': '2021-10-24 22:08:15'},
#  {'City': 'Pochutla',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 85.82,
#   'Humidity': 70,
#   'Cloudiness': 89,
#   'Wind Speed': 8.39,
#   'Country': 'MX',
#   'Date': '2021-10-24 22:10:58'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 25,
#   'Humidity': 58,
#   'Cloudiness': 49,
#   'Wind Speed': 5.86,
#   'Country': 'NO',
#   'Date': '2021-10-24 22:10:59'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 15.93,
#   'Humidity': 67,
#   'Cloudiness': 89,
#   'Wind Speed': 8.21,
#   'Country': 'GL',
#   'Date': '2021-10-24 22:10:59'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 57.9,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 9.33,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:11:00'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 74.57,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'RE',
#   'Date': '2021-10-24 22:07:10'},
#  {'City': 'Tiarei',
#   'Lat': -17.5333,
#   'Lng': -149.3333,
#   'Max Temp': 77.02,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 13.89,
#   'Country': 'PF',
#   'Date': '2021-10-24 22:11:00'},
#  {'City': 'Hangal',
#   'Lat': 14.7667,
#   'Lng': 75.1333,
#   'Max Temp': 67.53,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46,
#   'Country': 'IN',
#   'Date': '2021-10-24 22:11:01'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 67.55,
#   'Humidity': 37,
#   'Cloudiness': 5,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:11:01'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 56.1,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-10-24 22:11:02'},
#  {'City': 'Ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 48.74,
#   'Humidity': 67,
#   'Cloudiness': 81,
#   'Wind Speed': 8.61,
#   'Country': 'US',
#   'Date': '2021-10-24 22:11:02'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 9.18,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 18.19,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:03'},
#  {'City': 'Kuah',
#   'Lat': 6.3265,
#   'Lng': 99.8432,
#   'Max Temp': 80.1,
#   'Humidity': 79,
#   'Cloudiness': 97,
#   'Wind Speed': 1.63,
#   'Country': 'MY',
#   'Date': '2021-10-24 22:11:03'},
#  {'City': 'Fairmont',
#   'Lat': 39.4851,
#   'Lng': -80.1426,
#   'Max Temp': 70.38,
#   'Humidity': 77,
#   'Cloudiness': 72,
#   'Wind Speed': 4.29,
#   'Country': 'US',
#   'Date': '2021-10-24 22:11:04'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 81.21,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 21.85,
#   'Country': 'BB',
#   'Date': '2021-10-24 22:11:04'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 63.27,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-10-24 22:11:05'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 38.26,
#   'Humidity': 66,
#   'Cloudiness': 13,
#   'Wind Speed': 6.22,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:11:05'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 60.53,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'CL',
#   'Date': '2021-10-24 22:11:06'},
#  {'City': 'Pangody',
#   'Lat': 65.85,
#   'Lng': 74.4859,
#   'Max Temp': 22.73,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 15.43,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:06'},
#  {'City': 'Fukue',
#   'Lat': 32.6881,
#   'Lng': 128.8419,
#   'Max Temp': 61.68,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Country': 'JP',
#   'Date': '2021-10-24 22:07:03'},
#  {'City': 'Knysna',
#   'Lat': -34.0363,
#   'Lng': 23.0471,
#   'Max Temp': 53.67,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 4.54,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:11:07'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 42.42,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 18.99,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:11:07'},
#  {'City': 'Pitkyaranta',
#   'Lat': 61.5734,
#   'Lng': 31.4792,
#   'Max Temp': 33.73,
#   'Humidity': 72,
#   'Cloudiness': 91,
#   'Wind Speed': 9.28,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:08'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 82.36,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'TC',
#   'Date': '2021-10-24 22:06:22'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 66.25,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 21.85,
#   'Country': 'PE',
#   'Date': '2021-10-24 22:11:09'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 67.42,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'PT',
#   'Date': '2021-10-24 22:11:09'},
#  {'City': 'Talaja',
#   'Lat': 21.35,
#   'Lng': 72.05,
#   'Max Temp': 76.84,
#   'Humidity': 71,
#   'Cloudiness': 2,
#   'Wind Speed': 7.72,
#   'Country': 'IN',
#   'Date': '2021-10-24 22:11:10'},
#  {'City': 'Gerash',
#   'Lat': 27.6652,
#   'Lng': 54.1371,
#   'Max Temp': 69.55,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 4.09,
#   'Country': 'IR',
#   'Date': '2021-10-24 22:11:10'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 64.42,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'AR',
#   'Date': '2021-10-24 22:11:11'},
#  {'City': 'Vaitape',
#   'Lat': -16.5167,
#   'Lng': -151.75,
#   'Max Temp': 76.39,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 15.41,
#   'Country': 'PF',
#   'Date': '2021-10-24 22:11:12'},
#  {'City': 'Santa Vitoria Do Palmar',
#   'Lat': -33.5189,
#   'Lng': -53.3681,
#   'Max Temp': 60.93,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 7.25,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:11:12'},
#  {'City': 'Madison',
#   'Lat': 34.7334,
#   'Lng': -86.5667,
#   'Max Temp': 72.99,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-10-24 22:08:22'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 81.19,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 11.36,
#   'Country': 'OM',
#   'Date': '2021-10-24 22:11:13'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 44.02,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 3.67,
#   'Country': 'UZ',
#   'Date': '2021-10-24 22:11:13'},
#  {'City': 'Kidodi',
#   'Lat': -7.6036,
#   'Lng': 37.0044,
#   'Max Temp': 72.72,
#   'Humidity': 74,
#   'Cloudiness': 4,
#   'Wind Speed': 1.32,
#   'Country': 'TZ',
#   'Date': '2021-10-24 22:11:14'},
#  {'City': 'Roma',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 55.13,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-10-24 22:08:04'},
#  {'City': 'Mariana',
#   'Lat': -20.3778,
#   'Lng': -43.4161,
#   'Max Temp': 70.3,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.68,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:11:14'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 53.38,
#   'Humidity': 79,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-10-24 22:11:15'},
#  {'City': 'Mandalgovi',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 32.99,
#   'Humidity': 48,
#   'Cloudiness': 17,
#   'Wind Speed': 11.97,
#   'Country': 'MN',
#   'Date': '2021-10-24 22:11:15'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -4.61,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 11.97,
#   'Country': 'GL',
#   'Date': '2021-10-24 22:11:16'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 62.76,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 7.4,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:11:16'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 44.87,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 21.94,
#   'Country': 'NO',
#   'Date': '2021-10-24 22:11:17'},
#  {'City': 'Tessalit',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 87.42,
#   'Humidity': 19,
#   'Cloudiness': 38,
#   'Wind Speed': 10,
#   'Country': 'ML',
#   'Date': '2021-10-24 22:11:17'},
#  {'City': 'Manokwari',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 78.85,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26,
#   'Country': 'ID',
#   'Date': '2021-10-24 22:11:18'},
#  {'City': 'Novikovo',
#   'Lat': 51.1537,
#   'Lng': 37.8879,
#   'Max Temp': 35.42,
#   'Humidity': 76,
#   'Cloudiness': 50,
#   'Wind Speed': 11.56,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:18'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 75.6,
#   'Humidity': 73,
#   'Cloudiness': 55,
#   'Wind Speed': 10.74,
#   'Country': 'NC',
#   'Date': '2021-10-24 22:09:55'},
#  {'City': 'Port Moresby',
#   'Lat': -9.4431,
#   'Lng': 147.1797,
#   'Max Temp': 80.74,
#   'Humidity': 75,
#   'Cloudiness': 26,
#   'Wind Speed': 1.32,
#   'Country': 'PG',
#   'Date': '2021-10-24 22:11:19'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -15.03,
#   'Humidity': 99,
#   'Cloudiness': 29,
#   'Wind Speed': 5.03,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:09:11'},
#  {'City': 'Marsa Matruh',
#   'Lat': 31.3525,
#   'Lng': 27.2453,
#   'Max Temp': 70.7,
#   'Humidity': 73,
#   'Cloudiness': 7,
#   'Wind Speed': 8.86,
#   'Country': 'EG',
#   'Date': '2021-10-24 22:11:20'},
#  {'City': 'Gornyak',
#   'Lat': 50.9942,
#   'Lng': 81.4661,
#   'Max Temp': 41.68,
#   'Humidity': 52,
#   'Cloudiness': 22,
#   'Wind Speed': 12.66,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:20'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 71.74,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-10-24 22:06:55'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 78.57,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:11:21'},
#  {'City': 'Tukan',
#   'Lat': 53.8409,
#   'Lng': 57.4552,
#   'Max Temp': 34.61,
#   'Humidity': 98,
#   'Cloudiness': 72,
#   'Wind Speed': 2.46,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:21'},
#  {'City': 'Balabac',
#   'Lat': 7.9868,
#   'Lng': 117.0645,
#   'Max Temp': 81.18,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 12.33,
#   'Country': 'PH',
#   'Date': '2021-10-24 22:11:22'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -0.15,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.29,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:22'},
#  {'City': 'Sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 75.83,
#   'Humidity': 88,
#   'Cloudiness': 94,
#   'Wind Speed': 5.21,
#   'Country': 'MG',
#   'Date': '2021-10-24 22:11:23'},
#  {'City': 'Matagami',
#   'Lat': 49.7502,
#   'Lng': -77.6328,
#   'Max Temp': 40.26,
#   'Humidity': 69,
#   'Cloudiness': 98,
#   'Wind Speed': 4.45,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:11:23'},
#  {'City': 'Atambua',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 76.86,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 1.68,
#   'Country': 'ID',
#   'Date': '2021-10-24 22:11:24'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 65.98,
#   'Humidity': 71,
#   'Cloudiness': 16,
#   'Wind Speed': 3.6,
#   'Country': 'NZ',
#   'Date': '2021-10-24 22:11:24'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 89.15,
#   'Humidity': 21,
#   'Cloudiness': 58,
#   'Wind Speed': 9.73,
#   'Country': 'ML',
#   'Date': '2021-10-24 22:11:25'},
#  {'City': 'Morondava',
#   'Lat': -20.2833,
#   'Lng': 44.2833,
#   'Max Temp': 72.68,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 7.81,
#   'Country': 'MG',
#   'Date': '2021-10-24 22:11:25'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 82.09,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Country': 'GF',
#   'Date': '2021-10-24 22:11:26'},
#  {'City': 'Irbeyskoye',
#   'Lat': 55.6428,
#   'Lng': 95.4522,
#   'Max Temp': 43.2,
#   'Humidity': 70,
#   'Cloudiness': 88,
#   'Wind Speed': 16.22,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:26'},
#  {'City': 'Nuevo Progreso',
#   'Lat': 23.1667,
#   'Lng': -97.95,
#   'Max Temp': 89.6,
#   'Humidity': 57,
#   'Cloudiness': 93,
#   'Wind Speed': 4,
#   'Country': 'MX',
#   'Date': '2021-10-24 22:11:27'},
#  {'City': 'Vanimo',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 78.6,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.94,
#   'Country': 'PG',
#   'Date': '2021-10-24 22:09:37'},
#  {'City': 'Bassila',
#   'Lat': 9.0081,
#   'Lng': 1.6654,
#   'Max Temp': 74.97,
#   'Humidity': 82,
#   'Cloudiness': 84,
#   'Wind Speed': 3,
#   'Country': 'BJ',
#   'Date': '2021-10-24 22:11:28'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 0.43,
#   'Humidity': 89,
#   'Cloudiness': 77,
#   'Wind Speed': 16.55,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:28'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 50.92,
#   'Humidity': 88,
#   'Cloudiness': 92,
#   'Wind Speed': 25.72,
#   'Country': 'FO',
#   'Date': '2021-10-24 22:11:29'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 70.97,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 7.49,
#   'Country': 'SA',
#   'Date': '2021-10-24 22:09:09'},
#  {'City': 'Odweyne',
#   'Lat': 9.4092,
#   'Lng': 45.064,
#   'Max Temp': 72.41,
#   'Humidity': 38,
#   'Cloudiness': 4,
#   'Wind Speed': 7.14,
#   'Country': 'SO',
#   'Date': '2021-10-24 22:11:30'},
#  {'City': 'Krasnoarmeysk',
#   'Lat': 51.0239,
#   'Lng': 45.6969,
#   'Max Temp': 39.29,
#   'Humidity': 68,
#   'Cloudiness': 96,
#   'Wind Speed': 8.59,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:30'},
#  {'City': 'Ballina',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 69.78,
#   'Humidity': 91,
#   'Cloudiness': 57,
#   'Wind Speed': 6.73,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:08:32'},
#  {'City': 'Muisne',
#   'Lat': 0.6,
#   'Lng': -80.0333,
#   'Max Temp': 77.05,
#   'Humidity': 82,
#   'Cloudiness': 92,
#   'Wind Speed': 10.36,
#   'Country': 'EC',
#   'Date': '2021-10-24 22:09:18'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 75.47,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 2.64,
#   'Country': 'PH',
#   'Date': '2021-10-24 22:07:43'},
#  {'City': 'Inirida',
#   'Lat': 3.8653,
#   'Lng': -67.9239,
#   'Max Temp': 78.3,
#   'Humidity': 91,
#   'Cloudiness': 94,
#   'Wind Speed': 2.55,
#   'Country': 'CO',
#   'Date': '2021-10-24 22:10:55'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 23.59,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:21'},
#  {'City': 'Kitimat',
#   'Lat': 54.0524,
#   'Lng': -128.6534,
#   'Max Temp': 48.9,
#   'Humidity': 66,
#   'Cloudiness': 98,
#   'Wind Speed': 1.99,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:11:33'},
#  {'City': 'Kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 93.61,
#   'Humidity': 18,
#   'Cloudiness': 80,
#   'Wind Speed': 3.62,
#   'Country': 'ML',
#   'Date': '2021-10-24 22:11:34'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 11.97,
#   'Humidity': 80,
#   'Cloudiness': 63,
#   'Wind Speed': 5.57,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:08:41'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 75.22,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'MU',
#   'Date': '2021-10-24 22:11:34'},
#  {'City': 'Monrovia',
#   'Lat': 6.3005,
#   'Lng': -10.7969,
#   'Max Temp': 78.57,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'LR',
#   'Date': '2021-10-24 22:09:08'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 58.86,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 3.94,
#   'Country': 'NA',
#   'Date': '2021-10-24 22:10:40'},
#  {'City': 'Ayagoz',
#   'Lat': 47.9714,
#   'Lng': 80.4392,
#   'Max Temp': 35.64,
#   'Humidity': 44,
#   'Cloudiness': 5,
#   'Wind Speed': 6.76,
#   'Country': 'KZ',
#   'Date': '2021-10-24 22:11:35'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 75.29,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51,
#   'Country': 'PF',
#   'Date': '2021-10-24 22:11:35'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 28.42,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-10-24 22:11:36'},
#  {'City': 'Yumen',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 44.82,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind Speed': 14.2,
#   'Country': 'CN',
#   'Date': '2021-10-24 22:11:36'},
#  {'City': 'Mezen',
#   'Lat': 65.8522,
#   'Lng': 44.24,
#   'Max Temp': 28.27,
#   'Humidity': 86,
#   'Cloudiness': 42,
#   'Wind Speed': 12.88,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:37'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 74.89,
#   'Humidity': 69,
#   'Cloudiness': 65,
#   'Wind Speed': 17.38,
#   'Country': 'NU',
#   'Date': '2021-10-24 22:11:37'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 70.54,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 15.57,
#   'Country': 'MX',
#   'Date': '2021-10-24 22:07:48'},
#  {'City': 'Kupang',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 77.58,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'ID',
#   'Date': '2021-10-24 22:11:38'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 45.72,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.87,
#   'Country': 'IS',
#   'Date': '2021-10-24 22:11:39'},
#  {'City': 'Pingliang',
#   'Lat': 35.5392,
#   'Lng': 106.6861,
#   'Max Temp': 44.98,
#   'Humidity': 90,
#   'Cloudiness': 97,
#   'Wind Speed': 3.04,
#   'Country': 'CN',
#   'Date': '2021-10-24 22:11:39'},
#  {'City': 'Noumea',
#   'Lat': -22.2763,
#   'Lng': 166.4572,
#   'Max Temp': 78.78,
#   'Humidity': 99,
#   'Cloudiness': 19,
#   'Wind Speed': 9.35,
#   'Country': 'NC',
#   'Date': '2021-10-24 22:11:31'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 80.58,
#   'Humidity': 74,
#   'Cloudiness': 91,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:11:40'},
#  {'City': 'Belmonte',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 77.5,
#   'Humidity': 88,
#   'Cloudiness': 39,
#   'Wind Speed': 8.75,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:11:40'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 81.5,
#   'Humidity': 73,
#   'Cloudiness': 28,
#   'Wind Speed': 13.94,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:11:41'},
#  {'City': 'Zarate',
#   'Lat': -34.0981,
#   'Lng': -59.0286,
#   'Max Temp': 73.94,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 5.7,
#   'Country': 'AR',
#   'Date': '2021-10-24 22:11:41'},
#  {'City': 'Makat',
#   'Lat': 47.6469,
#   'Lng': 53.3463,
#   'Max Temp': 52.29,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'KZ',
#   'Date': '2021-10-24 22:11:42'},
#  {'City': 'Baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 32.05,
#   'Humidity': 93,
#   'Cloudiness': 88,
#   'Wind Speed': 5.3,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:42'},
#  {'City': 'Naifaru',
#   'Lat': 5.4444,
#   'Lng': 73.3657,
#   'Max Temp': 82.33,
#   'Humidity': 75,
#   'Cloudiness': 71,
#   'Wind Speed': 16.46,
#   'Country': 'MV',
#   'Date': '2021-10-24 22:11:43'},
#  {'City': 'Peniche',
#   'Lat': 39.3558,
#   'Lng': -9.3811,
#   'Max Temp': 61.61,
#   'Humidity': 91,
#   'Cloudiness': 17,
#   'Wind Speed': 6.82,
#   'Country': 'PT',
#   'Date': '2021-10-24 22:11:43'},
#  {'City': 'Imaculada',
#   'Lat': -7.3897,
#   'Lng': -37.5092,
#   'Max Temp': 80.17,
#   'Humidity': 39,
#   'Cloudiness': 67,
#   'Wind Speed': 6.62,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:11:44'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 68.07,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:11:44'},
#  {'City': 'Joao Pinheiro',
#   'Lat': -17.7425,
#   'Lng': -46.1725,
#   'Max Temp': 74.07,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 4.94,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:11:44'},
#  {'City': 'Vredendal',
#   'Lat': -31.6683,
#   'Lng': 18.5012,
#   'Max Temp': 63.66,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'ZA',
#   'Date': '2021-10-24 22:11:45'},
#  {'City': 'Viransehir',
#   'Lat': 37.2353,
#   'Lng': 39.7631,
#   'Max Temp': 61.88,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 4.36,
#   'Country': 'TR',
#   'Date': '2021-10-24 22:11:45'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 39.54,
#   'Humidity': 62,
#   'Cloudiness': 91,
#   'Wind Speed': 5.55,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:11:46'},
#  {'City': 'Labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 78.28,
#   'Humidity': 84,
#   'Cloudiness': 33,
#   'Wind Speed': 8.52,
#   'Country': 'ID',
#   'Date': '2021-10-24 22:10:35'},
#  {'City': 'Nazarovo',
#   'Lat': 56.0064,
#   'Lng': 90.3914,
#   'Max Temp': 41.88,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 13,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:46'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 21.22,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'GL',
#   'Date': '2021-10-24 22:11:47'},
#  {'City': 'Orange Cove',
#   'Lat': 36.6244,
#   'Lng': -119.3137,
#   'Max Temp': 73.45,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 3.22,
#   'Country': 'US',
#   'Date': '2021-10-24 22:08:53'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 64.76,
#   'Humidity': 80,
#   'Cloudiness': 2,
#   'Wind Speed': 9.82,
#   'Country': 'PT',
#   'Date': '2021-10-24 22:11:48'},
#  {'City': 'Akyab',
#   'Lat': 20.15,
#   'Lng': 92.9,
#   'Max Temp': 76.23,
#   'Humidity': 77,
#   'Cloudiness': 92,
#   'Wind Speed': 4.9,
#   'Country': 'MM',
#   'Date': '2021-10-24 22:11:48'},
#  {'City': 'Daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 82.53,
#   'Humidity': 79,
#   'Cloudiness': 91,
#   'Wind Speed': 10.31,
#   'Country': 'PG',
#   'Date': '2021-10-24 22:11:49'},
#  {'City': 'Erzin',
#   'Lat': 36.9559,
#   'Lng': 36.2,
#   'Max Temp': 68.72,
#   'Humidity': 76,
#   'Cloudiness': 2,
#   'Wind Speed': 1.83,
#   'Country': 'TR',
#   'Date': '2021-10-24 22:11:49'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 28.22,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-10-24 22:11:31'},
#  {'City': 'Severomuysk',
#   'Lat': 56.1481,
#   'Lng': 113.4267,
#   'Max Temp': 17.83,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 2.77,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:11:50'},
#  {'City': 'Honningsvag',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 35.42,
#   'Humidity': 73,
#   'Cloudiness': 46,
#   'Wind Speed': 11.86,
#   'Country': 'NO',
#   'Date': '2021-10-24 22:11:50'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 92.12,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 11.48,
#   'Country': 'US',
#   'Date': '2021-10-24 22:07:14'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 66.04,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:11:51'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 53.51,
#   'Humidity': 90,
#   'Cloudiness': 83,
#   'Wind Speed': 12.53,
#   'Country': 'GB',
#   'Date': '2021-10-24 22:11:52'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 55.31,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 14.7,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:11:52'},
#  {'City': 'Chaiyaphum',
#   'Lat': 15.75,
#   'Lng': 102,
#   'Max Temp': 67.84,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.03,
#   'Country': 'TH',
#   'Date': '2021-10-24 22:11:53'},
#  {'City': 'Caramay',
#   'Lat': 10.1815,
#   'Lng': 119.236,
#   'Max Temp': 78.87,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Country': 'PH',
#   'Date': '2021-10-24 22:11:53'},
#  {'City': 'Ambulu',
#   'Lat': -8.345,
# ...
#   'Cloudiness': 100,
#   'Wind Speed': 8.3,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:14:26'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 46.35,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'CL',
#   'Date': '2021-10-24 22:14:27'},
#  {'City': 'Nizhniy Baskunchak',
#   'Lat': 48.2198,
#   'Lng': 46.8311,
#   'Max Temp': 46.8,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 6.85,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:14:27'},
#  {'City': 'Bose',
#   'Lat': 45.4612,
#   'Lng': 8.0137,
#   'Max Temp': 53.24,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'IT',
#   'Date': '2021-10-24 22:14:28'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 42.17,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 17.72,
#   'Country': 'IS',
#   'Date': '2021-10-24 22:14:28'},
#  {'City': 'Hereford',
#   'Lat': 52.0568,
#   'Lng': -2.7148,
#   'Max Temp': 54.91,
#   'Humidity': 68,
#   'Cloudiness': 7,
#   'Wind Speed': 3,
#   'Country': 'GB',
#   'Date': '2021-10-24 22:14:29'},
#  {'City': 'Tocopilla',
#   'Lat': -22.092,
#   'Lng': -70.1979,
#   'Max Temp': 63.19,
#   'Humidity': 65,
#   'Cloudiness': 21,
#   'Wind Speed': 5.06,
#   'Country': 'CL',
#   'Date': '2021-10-24 22:11:53'},
#  {'City': 'Shelburne',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 49.57,
#   'Humidity': 67,
#   'Cloudiness': 88,
#   'Wind Speed': 3.69,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:14:29'},
#  {'City': 'Jalu',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 74.37,
#   'Humidity': 31,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'LY',
#   'Date': '2021-10-24 22:14:30'},
#  {'City': 'Maumere',
#   'Lat': -8.6199,
#   'Lng': 122.2111,
#   'Max Temp': 79.68,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 1.16,
#   'Country': 'ID',
#   'Date': '2021-10-24 22:14:30'},
#  {'City': 'Rafaela',
#   'Lat': -31.2503,
#   'Lng': -61.4867,
#   'Max Temp': 77.99,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 10.13,
#   'Country': 'AR',
#   'Date': '2021-10-24 22:14:31'},
#  {'City': 'Beysehir',
#   'Lat': 37.6773,
#   'Lng': 31.7246,
#   'Max Temp': 47.62,
#   'Humidity': 83,
#   'Cloudiness': 4,
#   'Wind Speed': 8.32,
#   'Country': 'TR',
#   'Date': '2021-10-24 22:14:31'},
#  {'City': 'Aksu',
#   'Lat': 41.1231,
#   'Lng': 80.2644,
#   'Max Temp': 46.99,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 4.27,
#   'Country': 'CN',
#   'Date': '2021-10-24 22:14:32'},
#  {'City': 'Griffith',
#   'Lat': 41.5284,
#   'Lng': -87.4237,
#   'Max Temp': 51.73,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2021-10-24 22:14:32'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 27.64,
#   'Humidity': 78,
#   'Cloudiness': 84,
#   'Wind Speed': 6.71,
#   'Country': 'NO',
#   'Date': '2021-10-24 22:14:33'},
#  {'City': 'Manado',
#   'Lat': 1.487,
#   'Lng': 124.8455,
#   'Max Temp': 74.17,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 1.14,
#   'Country': 'ID',
#   'Date': '2021-10-24 22:14:33'},
#  {'City': 'Barkot',
#   'Lat': 30.8167,
#   'Lng': 78.2,
#   'Max Temp': 51.04,
#   'Humidity': 76,
#   'Cloudiness': 32,
#   'Wind Speed': 4.74,
#   'Country': 'IN',
#   'Date': '2021-10-24 22:14:34'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 74.61,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Country': 'ID',
#   'Date': '2021-10-24 22:14:34'},
#  {'City': 'Sairang',
#   'Lat': 23.8,
#   'Lng': 92.6667,
#   'Max Temp': 66.29,
#   'Humidity': 95,
#   'Cloudiness': 3,
#   'Wind Speed': 1.83,
#   'Country': 'IN',
#   'Date': '2021-10-24 22:14:35'},
#  {'City': 'Urumqi',
#   'Lat': 43.801,
#   'Lng': 87.6005,
#   'Max Temp': 32.95,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'CN',
#   'Date': '2021-10-24 22:14:35'},
#  {'City': 'Ozernovskiy',
#   'Lat': 51.5,
#   'Lng': 156.5167,
#   'Max Temp': 37.31,
#   'Humidity': 83,
#   'Cloudiness': 84,
#   'Wind Speed': 17.38,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:12:18'},
#  {'City': 'Freeport',
#   'Lat': 40.6576,
#   'Lng': -73.5832,
#   'Max Temp': 59.25,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-10-24 22:10:59'},
#  {'City': 'Cozumel',
#   'Lat': 20.5083,
#   'Lng': -86.9458,
#   'Max Temp': 86.11,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Country': 'MX',
#   'Date': '2021-10-24 22:14:36'},
#  {'City': 'Sakakah',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 68.27,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 5.97,
#   'Country': 'SA',
#   'Date': '2021-10-24 22:14:36'},
#  {'City': 'Van',
#   'Lat': 38.4924,
#   'Lng': 43.3831,
#   'Max Temp': 38.55,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'TR',
#   'Date': '2021-10-24 22:14:37'},
#  {'City': 'Bundaberg',
#   'Lat': -24.85,
#   'Lng': 152.35,
#   'Max Temp': 79.09,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:14:37'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 77.11,
#   'Humidity': 88,
#   'Cloudiness': 93,
#   'Wind Speed': 7.81,
#   'Country': 'PH',
#   'Date': '2021-10-24 22:10:17'},
#  {'City': 'Kalaleh',
#   'Lat': 37.3807,
#   'Lng': 55.4916,
#   'Max Temp': 58.03,
#   'Humidity': 74,
#   'Cloudiness': 72,
#   'Wind Speed': 3.51,
#   'Country': 'IR',
#   'Date': '2021-10-24 22:14:38'},
#  {'City': 'Iberia',
#   'Lat': 29.9502,
#   'Lng': -91.7507,
#   'Max Temp': 81.1,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Date': '2021-10-24 22:14:39'},
#  {'City': 'Jardim',
#   'Lat': -21.4803,
#   'Lng': -56.1381,
#   'Max Temp': 72.82,
#   'Humidity': 64,
#   'Cloudiness': 80,
#   'Wind Speed': 6.44,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:14:39'},
#  {'City': 'Igrim',
#   'Lat': 63.1906,
#   'Lng': 64.4162,
#   'Max Temp': 28.02,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.12,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:14:39'},
#  {'City': 'Hohhot',
#   'Lat': 40.8106,
#   'Lng': 111.6522,
#   'Max Temp': 43.45,
#   'Humidity': 42,
#   'Cloudiness': 96,
#   'Wind Speed': 1.63,
#   'Country': 'CN',
#   'Date': '2021-10-24 22:14:40'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 24.24,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 2.51,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:14:40'},
#  {'City': 'Nakamura',
#   'Lat': 32.9833,
#   'Lng': 132.9333,
#   'Max Temp': 55.53,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.99,
#   'Country': 'JP',
#   'Date': '2021-10-24 22:14:41'},
#  {'City': 'Yayva',
#   'Lat': 59.3303,
#   'Lng': 57.2641,
#   'Max Temp': 39.18,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.19,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:14:41'},
#  {'City': 'Matamoros',
#   'Lat': 25.5333,
#   'Lng': -103.25,
#   'Max Temp': 87.91,
#   'Humidity': 19,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'MX',
#   'Date': '2021-10-24 22:13:11'},
#  {'City': 'Pierre',
#   'Lat': 44.3683,
#   'Lng': -100.351,
#   'Max Temp': 45.28,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Date': '2021-10-24 22:10:50'},
#  {'City': 'Weligama',
#   'Lat': 5.9667,
#   'Lng': 80.4167,
#   'Max Temp': 77.31,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 7.74,
#   'Country': 'LK',
#   'Date': '2021-10-24 22:14:42'},
#  {'City': 'Sarkand',
#   'Lat': 45.41,
#   'Lng': 79.9186,
#   'Max Temp': 43.79,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 3.91,
#   'Country': 'KZ',
#   'Date': '2021-10-24 22:14:42'},
#  {'City': 'Qarqin',
#   'Lat': 37.4185,
#   'Lng': 66.0436,
#   'Max Temp': 53.73,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 2.86,
#   'Country': 'AF',
#   'Date': '2021-10-24 22:14:43'},
#  {'City': 'Iracoubo',
#   'Lat': 5.4802,
#   'Lng': -53.2011,
#   'Max Temp': 78.28,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 9.84,
#   'Country': 'GF',
#   'Date': '2021-10-24 22:14:43'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 52.39,
#   'Humidity': 56,
#   'Cloudiness': 99,
#   'Wind Speed': 7.14,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:14:44'},
#  {'City': 'Omboue',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 77.13,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Country': 'GA',
#   'Date': '2021-10-24 22:11:49'},
#  {'City': 'Mamakan',
#   'Lat': 57.8161,
#   'Lng': 114.0028,
#   'Max Temp': 32.52,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.32,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:14:44'},
#  {'City': 'Pasir Gudang',
#   'Lat': 1.4584,
#   'Lng': 103.8805,
#   'Max Temp': 77.36,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'MY',
#   'Date': '2021-10-24 22:14:45'},
#  {'City': 'San Policarpo',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 80.38,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 3.11,
#   'Country': 'PH',
#   'Date': '2021-10-24 22:14:45'},
#  {'City': 'Minnedosa',
#   'Lat': 50.2453,
#   'Lng': -99.8436,
#   'Max Temp': 40.41,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 12.17,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:14:46'},
#  {'City': 'Luena',
#   'Lat': -11.7833,
#   'Lng': 19.9167,
#   'Max Temp': 65.52,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.63,
#   'Country': 'AO',
#   'Date': '2021-10-24 22:14:46'},
#  {'City': 'Veraval',
#   'Lat': 20.9,
#   'Lng': 70.3667,
#   'Max Temp': 78.22,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.94,
#   'Country': 'IN',
#   'Date': '2021-10-24 22:14:47'},
#  {'City': 'Rzhyshchiv',
#   'Lat': 49.9689,
#   'Lng': 31.0463,
#   'Max Temp': 42.17,
#   'Humidity': 75,
#   'Cloudiness': 89,
#   'Wind Speed': 6.2,
#   'Country': 'UA',
#   'Date': '2021-10-24 22:14:47'},
#  {'City': 'Soligalich',
#   'Lat': 59.0778,
#   'Lng': 42.2864,
#   'Max Temp': 26.46,
#   'Humidity': 93,
#   'Cloudiness': 59,
#   'Wind Speed': 7.52,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:14:48'},
#  {'City': 'Vondrozo',
#   'Lat': -22.8167,
#   'Lng': 47.2833,
#   'Max Temp': 70.07,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 3.09,
#   'Country': 'MG',
#   'Date': '2021-10-24 22:14:48'},
#  {'City': 'Hit',
#   'Lat': 33.6416,
#   'Lng': 42.8251,
#   'Max Temp': 69.58,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 8.28,
#   'Country': 'IQ',
#   'Date': '2021-10-24 22:14:49'},
#  {'City': 'Turayf',
#   'Lat': 31.6725,
#   'Lng': 38.6637,
#   'Max Temp': 64.99,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 8.9,
#   'Country': 'SA',
#   'Date': '2021-10-24 22:14:49'},
#  {'City': 'Sisophon',
#   'Lat': 13.5859,
#   'Lng': 102.9737,
#   'Max Temp': 70.77,
#   'Humidity': 89,
#   'Cloudiness': 95,
#   'Wind Speed': 7.67,
#   'Country': 'KH',
#   'Date': '2021-10-24 22:14:49'},
#  {'City': 'Diapaga',
#   'Lat': 12.0708,
#   'Lng': 1.7889,
#   'Max Temp': 79.47,
#   'Humidity': 58,
#   'Cloudiness': 18,
#   'Wind Speed': 3.87,
#   'Country': 'BF',
#   'Date': '2021-10-24 22:14:50'},
#  {'City': 'Luba',
#   'Lat': 3.4568,
#   'Lng': 8.5547,
#   'Max Temp': 79.23,
#   'Humidity': 88,
#   'Cloudiness': 57,
#   'Wind Speed': 5.19,
#   'Country': 'GQ',
#   'Date': '2021-10-24 22:14:51'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 62.67,
#   'Humidity': 58,
#   'Cloudiness': 8,
#   'Wind Speed': 11.56,
#   'Country': 'UY',
#   'Date': '2021-10-24 22:14:51'},
#  {'City': 'Boueni',
#   'Lat': -12.9025,
#   'Lng': 45.0761,
#   'Max Temp': 80.58,
#   'Humidity': 85,
#   'Cloudiness': 43,
#   'Wind Speed': 12.93,
#   'Country': 'YT',
#   'Date': '2021-10-24 22:14:52'},
#  {'City': 'Arkhangelsk',
#   'Lat': 64.5401,
#   'Lng': 40.5433,
#   'Max Temp': 30.31,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 13.42,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:14:52'},
#  {'City': 'Gobabis',
#   'Lat': -22.45,
#   'Lng': 18.9667,
#   'Max Temp': 67.06,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 4.32,
#   'Country': 'NA',
#   'Date': '2021-10-24 22:14:53'},
#  {'City': 'Shasta Lake',
#   'Lat': 40.6804,
#   'Lng': -122.3708,
#   'Max Temp': 58.35,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Date': '2021-10-24 22:14:53'},
#  {'City': 'Ugoofaaru',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 82.11,
#   'Humidity': 75,
#   'Cloudiness': 67,
#   'Wind Speed': 14.32,
#   'Country': 'MV',
#   'Date': '2021-10-24 22:14:54'},
#  {'City': 'Lerici',
#   'Lat': 44.0759,
#   'Lng': 9.9112,
#   'Max Temp': 60.6,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 10.33,
#   'Country': 'IT',
#   'Date': '2021-10-24 22:14:54'},
#  {'City': 'Hobbs',
#   'Lat': 32.7026,
#   'Lng': -103.136,
#   'Max Temp': 84.81,
#   'Humidity': 14,
#   'Cloudiness': 1,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2021-10-24 22:14:55'},
#  {'City': 'Trairi',
#   'Lat': -3.2778,
#   'Lng': -39.2689,
#   'Max Temp': 80.1,
#   'Humidity': 71,
#   'Cloudiness': 2,
#   'Wind Speed': 11.59,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:12:01'},
#  {'City': 'Mildura',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 54.07,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2021-10-24 22:14:55'},
#  {'City': 'Ishigaki',
#   'Lat': 24.3448,
#   'Lng': 124.1572,
#   'Max Temp': 77.43,
#   'Humidity': 74,
#   'Cloudiness': 88,
#   'Wind Speed': 18.25,
#   'Country': 'JP',
#   'Date': '2021-10-24 22:14:56'},
#  {'City': 'Zeya',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': 33.44,
#   'Humidity': 95,
#   'Cloudiness': 87,
#   'Wind Speed': 3.09,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:12:19'},
#  {'City': 'Karlivka',
#   'Lat': 49.4567,
#   'Lng': 35.1295,
#   'Max Temp': 39.31,
#   'Humidity': 66,
#   'Cloudiness': 95,
#   'Wind Speed': 9.6,
#   'Country': 'UA',
#   'Date': '2021-10-24 22:14:56'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 78.75,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:14:57'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 75.27,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 11.72,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:14:57'},
#  {'City': 'Inuvik',
#   'Lat': 68.3499,
#   'Lng': -133.7218,
#   'Max Temp': 27.45,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55,
#   'Country': 'CA',
#   'Date': '2021-10-24 22:12:35'},
#  {'City': 'Ternate',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 79.93,
#   'Humidity': 80,
#   'Cloudiness': 70,
#   'Wind Speed': 4.85,
#   'Country': 'ID',
#   'Date': '2021-10-24 22:14:58'},
#  {'City': 'Matias Romero',
#   'Lat': 16.8833,
#   'Lng': -95.0333,
#   'Max Temp': 82.81,
#   'Humidity': 71,
#   'Cloudiness': 68,
#   'Wind Speed': 10.33,
#   'Country': 'MX',
#   'Date': '2021-10-24 22:14:58'},
#  {'City': 'Rabo De Peixe',
#   'Lat': 37.8,
#   'Lng': -25.5833,
#   'Max Temp': 62.11,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'PT',
#   'Date': '2021-10-24 22:14:59'},
#  {'City': 'Herat',
#   'Lat': 34.5,
#   'Lng': 62,
#   'Max Temp': 53.47,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'AF',
#   'Date': '2021-10-24 22:14:59'},
#  {'City': 'Volokolamsk',
#   'Lat': 56.0336,
#   'Lng': 35.9694,
#   'Max Temp': 28.69,
#   'Humidity': 88,
#   'Cloudiness': 32,
#   'Wind Speed': 7.34,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:15:00'},
#  {'City': 'Santarem',
#   'Lat': -2.4431,
#   'Lng': -54.7083,
#   'Max Temp': 80.73,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'BR',
#   'Date': '2021-10-24 22:15:00'},
#  {'City': 'Simao',
#   'Lat': 22.7886,
#   'Lng': 100.9748,
#   'Max Temp': 60.24,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.83,
#   'Country': 'CN',
#   'Date': '2021-10-24 22:15:01'},
#  {'City': 'Siparia',
#   'Lat': 10.1333,
#   'Lng': -61.5,
#   'Max Temp': 81.07,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 11.32,
#   'Country': 'TT',
#   'Date': '2021-10-24 22:15:02'},
#  {'City': 'Dzhebariki-Khaya',
#   'Lat': 62.2167,
#   'Lng': 135.8,
#   'Max Temp': 27.72,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:12:16'},
#  {'City': 'Calera',
#   'Lat': 33.1029,
#   'Lng': -86.7536,
#   'Max Temp': 70.2,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-10-24 22:15:02'},
#  {'City': 'Puksoozero',
#   'Lat': 62.5903,
#   'Lng': 40.6066,
#   'Max Temp': 25.88,
#   'Humidity': 77,
#   'Cloudiness': 18,
#   'Wind Speed': 7.14,
#   'Country': 'RU',
#   'Date': '2021-10-24 22:15:03'}]

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Seoul  37.5683  126.9778     45.84        51          27
# 1     Kruisfontein -34.0033   24.7314     49.89        81           0
# 2           Bonthe   7.5264  -12.5050     78.22        86         100
# 3  Port Hawkesbury  45.6169  -61.3485     48.58        83          90
# 4           Kodiak  57.7900 -152.4072     45.91        76          90
# 5        Busselton -33.6500  115.3333     55.04        82         100
# 6         Waingapu  -9.6567  120.2641     78.64        84          79
# 7   Saint-Philippe -21.3585   55.7679     74.48        83          47
# 8            Tynda  55.1667  124.7167     28.67        94          39
# 9       Labytnangi  66.6572   66.4183     17.24        89          84
#
#    Wind Speed Country                 Date
# 0        1.86      KR  2021-10-24 22:09:14
# 1        3.11      ZA  2021-10-24 22:07:08
# 2        5.30      SL  2021-10-24 22:10:11
# 3        8.01      CA  2021-10-24 22:10:11
# 4        5.75      US  2021-10-24 22:09:20
# 5        9.91      AU  2021-10-24 22:10:12
# 6        1.48      ID  2021-10-24 22:05:15
# 7       16.37      RE  2021-10-24 22:10:13
# 8        0.27      RU  2021-10-24 22:10:13
# 9        6.73      RU  2021-10-24 22:10:13

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
